# %% [markdown]
# ## Homework 4: Understanding Risk-Aversion through Utility Theory
#
# ### Absolute and Relative Risk Premia
#
# **1. Calculating the Risk-Premium: **
#
# Taylor-expand $U(x)$ around $\overline{x}$, ignoring terms beyond quadratic
# $$U ( x ) \approx U ( \overline { x } ) + U ^ { \prime } ( \overline { x } ) \cdot ( x - \overline { x } ) + \frac { 1 } { 2 } U ^ { \prime \prime } ( \overline { x } ) \cdot ( x - \overline { x } ) ^ { 2 }$$
#
# Taylor-expand $U(xCE)$ around $\overline{x}$, ignoring terms beyond linear
# $$
# U \left( x _ { C E } \right) \approx U ( \overline { x } ) + U ^ { \prime } ( \overline { x } ) \cdot \left( x _ { C E } - \overline { x } \right)
# $$
#
# Taking the expectation of the $U(x)$ expansion, we get:
# $$
# \mathbb { E } [ U ( x ) ] \approx U ( \overline { x } ) + \frac { 1 } { 2 } \cdot U ^ { \prime \prime } ( \overline { x } ) \cdot \sigma _ { x } ^ { 2 }
# $$
#
# $
# \text { Since } \mathbb { E } [ U ( x ) ] = U \left( x _ { C E } \right) , \text { the above two expressions are } \approx . \text { Hence, }
# $
# $$
# U ^ { \prime } ( \overline { x } ) \cdot \left( x _ { C E } - \overline { x } \right) \approx \frac { 1 } { 2 } \cdot U ^ { \prime \prime } ( \overline { x } ) \cdot \sigma _ { x } ^ { 2 }
# $$
#
# From the last equation on the previous slide, Absolute Risk-Premium
# $$
# \pi _ { A } = \overline { x } - x _ { C E } \approx - \frac { 1 } { 2 } \cdot \frac { U ^ { \prime \prime } ( \overline { x } ) } { U ^ { \prime } ( \overline { x } ) } \cdot \sigma _ { x } ^ { 2 }
# $$
#
# **2. Absolute Risk-Aversion: **
# $$
# A ( x ) = - \frac { U ^ { \prime \prime } ( x ) } { U ^ { \prime } ( x ) }
# $$
# **3. Relative Risk-Aversion: **
# $$
# R ( x ) = - \frac { U ^ { \prime \prime } ( x ) \cdot x } { U ^ { \prime } ( x ) }
# $$
#
#
# ### Portfolio Application
#
# **1. CARA utility function: **
# $$
# U ( x ) = \frac { - e ^ { - a x } } { a } \text { for } a \neq 0
# $$
# $A ( x ) = \frac { - U ^ { \prime \prime } ( x ) } { U ^ { \prime } ( x ) } = a$ is Coefficient of Constant Absolute Risk-Aversion.
#
# If the random outcome $x \sim \mathcal { N } \left( \mu , \sigma ^ { 2 } \right)$,
# $$
# \mathbb { E } [ U ( x ) ] = \left\{ \begin{array} { l l } { \frac { - e ^ { - s \mu + \frac { a ^ { 2 } \sigma ^ { 2 } } { 2 } } } { a } } & { \text { for } a \neq 0 } \\ { \mu } & { \text { for } a = 0 } \end{array} \right.
# $$
# $$
# x _ { C E } = \mu - \frac { a \sigma ^ { 2 } } { 2 }
# $$
#
# Portfolio Wealth is modelled as
# $$
# W \sim \mathcal { N } \left( 1 + r + \pi ( \mu - r ) , \pi ^ { 2 } \sigma ^ { 2 } \right)
# $$
# From the section on CARA Utility, we know we need to maximize:
# $$
# 1 + r + \pi ( \mu - r ) - \frac { a \pi ^ { 2 } \sigma ^ { 2 } } { 2 }
# $$
# So optimal investment fraction in risky asset
# $$
# \pi ^ { * } = \frac { \mu - r } { a \sigma ^ { 2 } }
# $$
#
# **2. CRRA utility function: **
# $$
# U ( x ) = \frac { x ^ { 1 - \gamma } } { 1 - \gamma }
# $$
# $R ( x ) = \frac { - U ^ { \prime \prime } ( x ) \cdot x } { U ^ { \prime } ( x ) } = \gamma$ is  Coefficient of Constant Relative Risk-Aversion.
#
# If the random outcome x is lognormal, with $\log ( x ) \sim \mathcal { N } \left( \mu , \sigma ^ { 2 } \right)$,
# $$
# \mathbb { E } [ U ( x ) ] = \left\{ \begin{array} { l l } { \frac { e ^ { \mu ( 1 - \gamma ) + \frac { \sigma ^ { 2 } } { 2 } ( 1 - \gamma ) ^ { 2 } } } { 1 - \gamma } } & { \text { for } \gamma \neq 1 } \\ { \mu } & { \text { for } \gamma = 1 } \end{array} \right.
# $$
# $$
# x _ { C E } = e ^ { \mu + \frac { \sigma ^ { 2 } } { 2 } ( 1 - \gamma ) }
# $$
#
# The process for wealth $W_t$ is given by
# $$
# d W _ { t } = ( r + \pi ( \mu - r ) ) \cdot W _ { t } \cdot d t + \pi \cdot \sigma \cdot W _ { t } \cdot d z _ { t }
# $$
# Applying Ito’s Lemma on log Wt gives us:
# $$
# \begin{aligned} \log W _ { t } & = \int _ { 0 } ^ { t } \left( r + \pi ( \mu - r ) - \frac { \pi ^ { 2 } \sigma ^ { 2 } } { 2 } \right) \cdot d u + \int _ { 0 } ^ { t } \pi \cdot \sigma \cdot d z _ { u } \\ & \Rightarrow \log W \sim \mathcal { N } \left( r + \pi ( \mu - r ) - \frac { \pi ^ { 2 } \sigma ^ { 2 } } { 2 } , \pi ^ { 2 } \sigma ^ { 2 } \right) \end{aligned}
# $$
# From the section on CRRA Utility, we know we need to maximize:
# $$
# \begin{array} { c } { r + \pi ( \mu - r ) - \frac { \pi ^ { 2 } \sigma ^ { 2 } } { 2 } + \frac { \pi ^ { 2 } \sigma ^ { 2 } ( 1 - \gamma ) } { 2 } } \\ { = r + \pi ( \mu - r ) - \frac { \pi ^ { 2 } \sigma ^ { 2 } \gamma } { 2 } } \end{array}
# $$
# So optimal investment fraction in risky asset
# $$
# \pi ^ { * } = \frac { \mu - r } { \gamma \sigma ^ { 2 } }
# $$
